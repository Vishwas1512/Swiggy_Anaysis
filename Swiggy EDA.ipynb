# %% [markdown]
# **SWIGGY SALES EDA**

# %%
#Importing Libraries 
import pandas as pd 
import  numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Load the DataSet
df=pd.read_csv("C:\\Users\\VISHWAS\\Downloads\\swiggy.csv")

# %%
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
# Check for Size
df.size
# Out:
# 86800

# %%
# Check for shape of dataset
df.shape
# Out:
# (8680, 10)

# %%
# Check for null values
df.isnull().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
#Check the Head and Tail of the Dataset
df.tail()
# Out:
#           ID                    Area       City                Restaurant  \
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings                   Food type  \
# 8675  500.0          2.9             80                      Pizzas
# 8676  200.0          2.9             80                South Indian
# 8677  150.0          2.9             80      Chinese,Snacks,Tandoor
# 8678  150.0          2.9             80  North Indian,Indian,Snacks
# 8679  250.0          2.9             80        Chaat,Snacks,Chinese
#
#           Address  Delivery time
# 8675  Navrangpura             40
# 8676       Rohini             28
# ...

# %%
df.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
# Check for duplicates
duplicates=df.duplicated().sum()
duplicates
# Out:
# 0

# %%
df.describe()
# Out:
#                   ID        Price  Avg ratings  Total ratings  Delivery time
# count    8680.000000  8680.000000  8680.000000    8680.000000    8680.000000
# mean   244812.071429   348.444470     3.655104     156.634793      53.967051
# std    158671.617188   230.940074     0.647629     391.448014      14.292335
# min       211.000000     0.000000     2.000000      20.000000      20.000000
# 25%     72664.000000   200.000000     2.900000      50.000000      44.000000
# 50%    283442.000000   300.000000     3.900000      80.000000      53.000000
# 75%    393425.250000   400.000000     4.200000     100.000000      64.000000
# max    466928.000000  2500.000000     5.000000   10000.000000     109.000000

# %%
df['Area'].unique()
# Out:
# array(['Koramangala', 'Jogupalya', 'Indiranagar', 'Domlur', 'Cooke Town',
#        'Pulikeshi Nagar', 'Sivanchetti Gardens', 'Kodihalli', 'Jayanagar',
#        'Film Nagar', 'Banashankari', 'Masab Tank', 'Banjara Hills',
#        'Andheri East', 'Powai', 'Punjagutta', 'Aundh', 'Baner',
#        'Powai Area', 'Ramgopalpet', 'Kalasiguda', 'Adarsh Nagar',
#        'Himayatnagar', 'Ashok Nagar', 'Commercial Street',
#        'Richmond Town', 'Vasanth Nagar', 'Bhowanipore', 'Ballygunge',
#        'Gariahat', 'Kalighat', 'Sion', 'Mumbai', 'Rajajinagar', 'Golpark',
#        'Shivajinagar', 'Koregaon Park', 'Deccan Gymkhana', 'Karkhana',
#        'Kothrud', 'Erandwane', 'Koti', 'Dilsukhnagar', 'Nagole',
#        'Chandrapuri Colony', 'Kothapet', 'Narayanguda', 'Fc Road',
#        'Park Street Area', 'Beniapukur', 'Bidhannagar', 'New Nallakunta',
#        'Adikmet', 'Amberpet', 'Karve Nagar', 'Agarkar Nagar', 'Mundhwa',
# ...

# %%
df['City'].unique()
# Out:
# array(['Bangalore', 'Hyderabad', 'Mumbai', 'Pune', 'Kolkata', 'Delhi',
#        'Chennai', 'Ahmedabad', 'Surat'], dtype=object)

# %% [markdown]
# **Number of Restaurants listed in each City**

# %%
No_of_Resturants_per_city=df.groupby('City')['Restaurant'].count().reset_index(name='Total_Restaurants').sort_values(by='Total_Restaurants', ascending=False)

# %% [markdown]
# **Top 10 Areas**

# %%
top_10_areas = df['Area'].value_counts().head(10)

# %%
top_10_areas
# Out:
# Area
# Rohini          257
# Chembur         208
# Kothrud         149
# Andheri East    135
# Navrangpura     132
# Indiranagar     130
# Kurla           129
# Koramangala     124
# Bidhannagar     123
# Ashok Nagar     118
# Name: count, dtype: int64

# %% [markdown]
# **Top 5 Cities**

# %%
Top_5_City = df['City'].value_counts().head(5)
Top_5_City
# Out:
# City
# Kolkata      1346
# Mumbai       1277
# Chennai      1106
# Pune         1090
# Hyderabad    1075
# Name: count, dtype: int64

# %%
b= df['Restaurant'].value_counts().head(10).plot(kind='bar', title="Shops")
b.set_xlabel("Shops")
b.set_ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
df.describe()
# Out:
#                   ID        Price  Avg ratings  Total ratings  Delivery time
# count    8680.000000  8680.000000  8680.000000    8680.000000    8680.000000
# mean   244812.071429   348.444470     3.655104     156.634793      53.967051
# std    158671.617188   230.940074     0.647629     391.448014      14.292335
# min       211.000000     0.000000     2.000000      20.000000      20.000000
# 25%     72664.000000   200.000000     2.900000      50.000000      44.000000
# 50%    283442.000000   300.000000     3.900000      80.000000      53.000000
# 75%    393425.250000   400.000000     4.200000     100.000000      64.000000
# max    466928.000000  2500.000000     5.000000   10000.000000     109.000000

# %% [markdown]
# # UniVarate

# %%
plt.Figure(figsize=(8,10))
sns.boxplot(df['Price'])
plt.title('Boxplot of Price')
plt.show()

# %% [markdown]
# **Removing outliers**

# %%
Price_Q1=df['Price'].quantile(0.25)

# %%
Price_Q3=df['Price'].quantile(0.75)

# %%
Price_IQR =Price_Q3-Price_Q1

# %%
Price_IQR
# Out:
# 200.0

# %%
Price_lower=Price_Q1-1.5*Price_IQR
Price_higher=Price_Q3+1.5*Price_IQR

# %%
df = df[(df['Price'] >= Price_lower) & (df['Price'] <= Price_higher)]

# %%
plt.Figure(figsize=(8,10))
plt.boxplot(df['Price'])
plt.title('Boxplot of Price')
plt.show()

# %%
plt.Figure(figsize=(8,10))
plt.boxplot(df['Avg ratings'])
plt.title('Boxplot of Avg ratings')
plt.show()

# %%
plt.Figure(figsize=(8,10))
plt.boxplot(df['Total ratings'])
plt.title('Boxplot of Total ratings')
plt.show()

# %% [markdown]
# **Removing outliers**

# %%
Total_ratings_Q1=df['Total ratings'].quantile(0.25)

# %%
Total_ratings_Q3=df['Total ratings'].quantile(0.75)

# %%
Total_ratings_IQR = Total_ratings_Q3-Total_ratings_Q1

# %%
Total_ratings_lower = Total_ratings_Q1-1.5*Total_ratings_IQR
Total_ratings_higher = Total_ratings_Q3+1.5*Total_ratings_IQR

# %%
df=df[(df['Total ratings']>=Total_ratings_lower) & (df['Total ratings']<=Total_ratings_higher)]

# %%
plt.Figure(figsize=(8,10))
plt.boxplot(df['Total ratings'])
plt.title('Boxplot of Total ratings')
plt.show()

# %%
plt.Figure(figsize=(8,10))
plt.boxplot(df['Delivery time'])
plt.title('Boxplot of Delivery time')
plt.show()

# %% [markdown]
# **Removing outliers**

# %%
Delivery_time_Q1 = df['Delivery time'].quantile(0.25)
Delivery_time_Q3 = df['Delivery time'].quantile(0.75)

# %%
Delivery_time_IQR=Delivery_time_Q3-Delivery_time_Q1

# %%
Delivery_time_lower=Delivery_time_Q1-1.5*Delivery_time_IQR
Delivery_time_Higher=Delivery_time_Q3-1.5*Delivery_time_IQR

# %%
df=df[(df['Delivery time'] >= Delivery_time_lower) & (df['Total ratings'] <= Delivery_time_Higher)]

# %%
plt.Figure(figsize=(8,10))
plt.boxplot(df['Delivery time'])
plt.title('Boxplot of Delivery time')
plt.show()

# %% [markdown]
# # BiVarate

# %%
sorted_df = df.sort_values(by='Delivery time', ascending=False).head(10)
plt.figure(figsize=(10, 8))
plt.bar(sorted_df['Area'], sorted_df['Delivery time'])
plt.xlabel('Area')
plt.ylabel('Delivery time')
plt.title('Top 10 Areas by Delivery Time')
plt.xticks(rotation=45) 
plt.show()

# %%
sorted_df = df.sort_values(by='Price', ascending=False).head(10)
# Plotting
plt.figure(figsize=(8,6))
plt.bar(sorted_df['Area'], sorted_df['Price'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.title('Top 10 Areas by Sales')
plt.show()

# %%
sorted_df = df.sort_values(by='Total ratings', ascending=False).head(10)
# Plotting
plt.figure(figsize=(8, 6))
plt.bar(sorted_df['Area'], sorted_df['Total ratings'])
plt.xlabel('Area')
plt.ylabel('Total ratings')
plt.xticks(rotation=45)
plt.title('Top 10 Areas by Total ratings')
plt.show()

# %%
# Plotting
plt.figure(figsize=(8, 6))
plt.bar(df['City'], df['Price'])
plt.xlabel('City')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.title('Barplot City by Sales')
plt.show()

# %%
sorted_df = df.sort_values(by='Price', ascending=False).head(10)
# Plotting
plt.figure(figsize=(8, 6))
plt.bar(sorted_df['Restaurant'], sorted_df['Price'])
plt.xlabel('Resturants')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.title('Top 10 Resturants by Sales')
plt.show()

# %%
sorted_df = df.sort_values(by='Total ratings', ascending=False).head(10)
# Plotting
plt.figure(figsize=(8, 6))
plt.bar(sorted_df['Restaurant'], sorted_df['Total ratings'])
plt.xlabel('Restaurant')
plt.ylabel('Total ratings')
plt.xticks(rotation=60)
plt.title('Top 10 Restaurants by Total ratings')
plt.show()

# %%
sorted_df = df.sort_values(by='Avg ratings', ascending=False).head(10)
# Plotting
plt.figure(figsize=(8, 6))
plt.bar(sorted_df['Food type'], sorted_df['Avg ratings'])
plt.xlabel('Food type')
plt.ylabel('Avg ratings')
plt.xticks(rotation=90)
plt.title('Top 10 Food types by Ratings')
plt.show()

# %%
sorted_df = df.sort_values(by='Avg ratings', ascending=False).head(10)
# Plotting
plt.figure(figsize=(8, 6))
plt.bar(sorted_df['Food type'], sorted_df['Avg ratings'])
plt.xlabel('Food type')
plt.ylabel('Avg ratings')
plt.xticks(rotation=90)
plt.title('Top 10 Food types by Ratings')
plt.show()

# %% [markdown]
# # MultiVarate

# %%
numeric_data=df.select_dtypes(include='number')
corr=numeric_data.corr()
corr
# Out:
#                      ID     Price  Avg ratings  Total ratings  Delivery time
# ID             1.000000 -0.061317     0.053664            NaN       0.087257
# Price         -0.061317  1.000000     0.074947            NaN       0.060029
# Avg ratings    0.053664  0.074947     1.000000            NaN      -0.067733
# Total ratings       NaN       NaN          NaN            NaN            NaN
# Delivery time  0.087257  0.060029    -0.067733            NaN       1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
sns.pairplot(df[['ID', 'Price', 'Avg ratings', 'Total ratings','Delivery time']].astype(float))
plt.title('Pair Plot of Variables')
plt.show()

# %% [markdown]
# * Customer Demographics by Area and City:
# The data includes information on delivery times and orders placed in different areas and cities like Koramangala and Indiranagar in Bangalore. This insight allows Swiggy to analyze demand patterns and adjust operational capacity according to the area's delivery performance.
# * Restaurant Pricing and Ratings:
# Restaurants such as Tandoor Hut and Kim Lee have high average ratings (4.4), while New Punjabi Hotel has a slightly lower rating (3.9). Evaluating ratings alongside pricing can help in identifying high-performing, cost-effective restaurants that customers prefer.

# %% [markdown]
# * Restaurant Performance by Total Ratings:
# Restaurants with a high number of total ratings, such as New Punjabi Hotel (500 ratings), indicate popularity and a large customer base. Monitoring customer feedback from these restaurants can provide Swiggy with critical insights to maintain service quality

# %% [markdown]
# * Delivery Time Analysis:
# Delivery times vary across areas, with Indiranagar having longer average delivery times (63 minutes for Nh8) compared to other areas. Swiggy can focus on optimizing delivery routes or increasing the number of delivery personnel in such high-traffic areas to reduce delays.
